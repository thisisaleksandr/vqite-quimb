# %%
"""
This notebook demonstrates how to use tensor-network implementation 
of the VQITE simulation.
The main code, relevant description, and package requirements are 
listed in avqite_quimb.py.
"""

# %%
import numpy as np
import scipy
import pickle
import time
from tqdm import tqdm
from typing import (
    List,
    Optional,
    Tuple,
    Union
)
import random
import importlib

import quimb as qu
import quimb.tensor as qtn

import cotengra as ctg

import avqite_quimb

importlib.reload(avqite_quimb)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# <module 'avqite_quimb' from '/Users/Aleksei/avqite-quimb/avqite_quimb.py'>

# %%
#File ansatz_inp.pkle contains the final ansatz generated by AVQITE

test_obj = avqite_quimb.Quimb_vqite(
    incar_file = "adaptvqite/adaptvqite/incars/incarN12g0.1",
    ansatz_file = "adaptvqite/adaptvqite/data/ansatz_inp.pkle",
    init_params = "random"
)

# %%
#Initial parameter values

test_obj._params
# Out:
# [-0.06990207223960712,
#  -0.02774358066546316,
#  0.023960162133500745,
#  -0.08467902340474108,
#  0.0750601571022814,
#  -0.003123859097461934,
#  0.071820191587425,
#  -0.011840619074683964,
#  -0.09578632118842781,
#  -0.006310528395671769,
#  0.055797469905707275,
#  -0.049751148954776905,
#  -0.0885574263915069,
#  -0.09579256220448949,
#  -0.08719827554315861,
#  0.06864937700608145,
#  0.09384008801668028,
#  0.052346208717667625,
#  -0.04816990115789841,
#  0.05148400361256428,
#  0.012333352653184915]

# %% [markdown]
# ### AVQITE results

# %% [markdown]
# e = -12.02998224

# %%
test_obj._params_solution
# Out:
# [-0.03373891838404348,
#  -0.050078497033246835,
#  -0.04991639034653487,
#  -0.024964345407657868,
#  -0.049755843269241644,
#  -0.04989684794910913,
#  -0.049917295159514666,
#  -0.04991848825801717,
#  -0.03373880318968922,
#  0.023566888103175317,
#  -0.04993780407632377,
#  -9.060913728609124e-06,
#  -2.1727417925979092e-05,
#  -2.0666081313686814e-05,
#  -0.04975599567846892,
#  -0.01613088640936399,
#  -0.01613095926996059,
#  -2.1592095145783832e-05,
#  -0.07350141136452552,
#  9.920607797867385e-05,
#  -0.02496434540765841]

# %% [markdown]
# ### Case with simplification 'CSR' and without the reuse of contraction paths

# %%
#keyboard interupted before the convergence

test_obj.vqite(optimize_m='greedy',optimize_v='greedy',simplify_sequence = 'CSR',backend=None)
# Out:
# iter:  0 , M matrix time:  4.426983833312988 , V vector time:  10.290584087371826 , Energy:  (-11.97515296982525+2.1450930104828054e-17j)
# iter:  1 , M matrix time:  0.37796783447265625 , V vector time:  10.299630165100098 , Energy:  (-11.983560761886997-2.7067693998323895e-17j)
# iter:  2 , M matrix time:  0.3460710048675537 , V vector time:  10.479669094085693 , Energy:  (-11.99068094390357-7.434464393359621e-18j)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 #keyboard interupted before the convergence
# ----> 3 test_obj.vqite(optimize_m='greedy',optimize_v='greedy',simplify_sequence = 'CSR',backend=None)
#
# File ~/avqite-quimb/avqite_quimb.py:366, in Quimb_vqite.vqite(self, delta, dt, optimize_m, optimize_v, **kwargs)
#     360     self.compute_m(
#     361         optimize=optimize_m,
#     362         which_nonzero=self.which_nonzero,
#     363         **kwargs
#     364     )
#     365 t2 = time.time()
# --> 366 self.compute_v(optimize=optimize_v,**kwargs)
#     367 t3 = time.time()
#     368 dthdt = self.get_dthdt(delta = delta, m = self._m, v= self._v)
#
# File ~/avqite-quimb/avqite_quimb.py:283, in Quimb_vqite.compute_v(self, **kwargs)
#     278 params2 = self._params.copy()
#     279 params2[mu] = params2[mu]-np.pi/2
#     280 self._v[mu] = np.real(
#     281     -1/2*(
#     282         self.h_exp_val(params=params1, **kwargs) -
# --> 283         self.h_exp_val(params=params2, **kwargs)
#     284     ) / 2
#     285 )
#
# File ~/avqite-quimb/avqite_quimb.py:433, in Quimb_vqite.h_exp_val(self, params, optimize, **kwargs)
#     431         h_exp_vals.append(exp_val)
#     432     else:
# --> 433         h_exp_vals.append( p_str_exp_eval(
#     434             qc=qc,
#     435             pauli_str=pauli_str,
#     436             optimize = optimize,
#     437             **kwargs
#     438         ) )
#     439 exp_value = sum([h_exp_vals[i]*self._H.coefs[i]
#     440                             for i in range(len(self._H.coefs))])
#     442 return exp_value
#
# File ~/avqite-quimb/avqite_quimb.py:816, in p_str_exp_eval(qc, pauli_str, **kwargs)
#     814 for i in range(1,len(where)):
#     815     operator = operator & qu.pauli(paulis[i])
# --> 816 exp_val = qc.local_expectation(
#     817     operator,
#     818     where,
#     819     **kwargs
#     820 )
#     821 return exp_val
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2882, in Circuit.local_expectation(self, G, where, optimize, simplify_sequence, simplify_atol, simplify_equalize_norms, backend, dtype, rehearse)
#    2874     where = (where,)
#    2876 fs_opts = {
#    2877     "seq": simplify_sequence,
#    2878     "atol": simplify_atol,
#    2879     "equalize_norms": simplify_equalize_norms,
#    2880 }
# -> 2882 rho = self.get_rdm_lightcone_simplified(where=where, **fs_opts)
#    2883 k_inds = tuple(self.ket_site_ind(i) for i in where)
#    2884 b_inds = tuple(self.bra_site_ind(i) for i in where)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2559, in Circuit.get_rdm_lightcone_simplified(self, where, seq, atol, equalize_norms)
#    2556 output_inds = b_inds + k_inds
#    2558 # # simplify the norm and cache it
# -> 2559 rho_lc.full_simplify_(
#    2560     seq=seq,
#    2561     atol=atol,
#    2562     output_inds=output_inds,
#    2563     equalize_norms=equalize_norms,
#    2564 )
#    2565 self._storage[key] = rho_lc
#    2567 # return a copy so we can modify it inplace
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:10544, in TensorNetwork.full_simplify(self, seq, output_inds, atol, equalize_norms, cache, inplace, progbar, rank_simplify_opts, loop_simplify_opts, split_simplify_opts, custom_methods, split_method)
#   10542     tn.column_reduce_(output_inds=ix_o, atol=atol, cache=cache)
#   10543 elif meth == 'S':
# > 10544     tn.split_simplify_(atol=atol, cache=cache,
#   10545                        equalize_norms=equalize_norms,
#   10546                        **split_simplify_opts)
#   10547 elif meth == 'L':
#   10548     tn.loop_simplify_(output_inds=ix_o, cutoff=atol,
#   10549                       cache=cache,
#   10550                       equalize_norms=equalize_norms,
#   10551                       **loop_simplify_opts)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:9782, in TensorNetwork.split_simplify(self, atol, equalize_norms, cache, inplace, **split_opts)
#    9780 found = False
#    9781 for lix, rix in gen_bipartitions(t.inds):
# -> 9782     tl, tr = t.split(
#    9783         lix,
#    9784         right_inds=rix,
#    9785         get="tensors",
#    9786         cutoff=atol,
#    9787         **split_opts,
#    9788     )
#    9789     new_size = max(tl.size, tr.size)
#    9790     if new_size < t.size:
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:2208, in Tensor.split(self, *args, **kwargs)
#    2206 @functools.wraps(tensor_split)
#    2207 def split(self, *args, **kwargs):
# -> 2208     return tensor_split(self, *args, **kwargs)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:546, in tensor_split(T, left_inds, method, get, absorb, max_bond, cutoff, cutoff_mode, renorm, ltags, rtags, stags, bond_ind, right_inds)
#     544         array = T
#     545 else:
# --> 546     TT = T.transpose(*left_inds, *right_inds)
#     547     left_dims = TT.shape[: len(left_inds)]
#     548     right_dims = TT.shape[len(left_inds) :]
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:1957, in Tensor.transpose(self, inplace, *output_inds)
#    1932 def transpose(self, *output_inds, inplace=False):
#    1933     """Transpose this tensor - permuting the order of both the data *and*
#    1934     the indices. This operation is mainly for ensuring a certain data
#    1935     layout since for most operations the specific order of indices doesn't
#    (...)
#    1955     transpose_like, reindex
#    1956     """
# -> 1957     t = self if inplace else self.copy()
#    1959     output_inds = tuple(output_inds)  # need to re-use this.
#    1960     if t.inds == output_inds:
#    1961         # no need to do anything
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:11190, in PTensor.copy(self)
#   11188 def copy(self):
#   11189     """Copy this parametrized tensor."""
# > 11190     return PTensor.from_parray(
#   11191         self._data.copy(),
#   11192         inds=self.inds,
#   11193         tags=self.tags,
#   11194         left_inds=self.left_inds,
#   11195     )
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:11180, in PTensor.from_parray(cls, parray, inds, tags, left_inds)
#   11177 @classmethod
#   11178 def from_parray(cls, parray, inds=(), tags=None, left_inds=None):
#   11179     obj = cls.__new__(cls)
# > 11180     super(PTensor, obj).__init__(
#   11181         parray,
#   11182         inds=inds,
#   11183         tags=tags,
#   11184         left_inds=left_inds,
#   11185     )
#   11186     return obj
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:1359, in Tensor.__init__(self, data, inds, tags, left_inds)
#    1357 self._set_data(data)
#    1358 self._set_inds(inds)
# -> 1359 self._set_tags(tags)
#    1360 self._set_left_inds(left_inds)
#    1362 if ndim(self._data) != len(self._inds):
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:1380, in Tensor._set_tags(self, tags)
#    1379 def _set_tags(self, tags):
# -> 1380     self._tags = tags_to_oset(tags)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:111, in tags_to_oset(tags)
#     109     return oset((tags,))
#     110 elif isinstance(tags, oset):
# --> 111     return tags.copy()
#     112 else:
#     113     return oset(tags)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/utils.py:353, in oset.copy(self)
#     352 def copy(self):
# --> 353     return oset.from_dict(self._d)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/utils.py:347, in oset.from_dict(cls, d)
#     344     obj._d = d
#     345     return obj
# --> 347 @classmethod
#     348 def from_dict(cls, d):
#     349     """Public method makes sure to copy incoming dictionary."""
#     350     return oset._from_dict(d.copy())
#
# KeyboardInterrupt:

# %%
test_obj._e
# Out:
# (-11.99068094390357-7.434464393359621e-18j)

# %%
test_obj._params
# Out:
# [-0.05799408495092694,
#  -0.025129854233312612,
#  0.01082382598681194,
#  -0.08520085448066918,
#  0.047347383621748215,
#  0.0030214369761656147,
#  0.06329089863764481,
#  -0.02024730862151857,
#  -0.09282758520627657,
#  -0.007504011444035096,
#  0.032476154914112994,
#  -0.03280783498610128,
#  -0.08544584720353016,
#  -0.09305895702100772,
#  -0.0790619519900448,
#  0.060740429914721256,
#  0.06558685130617954,
#  0.037578726312893,
#  -0.045997866789007184,
#  0.03255771901845972,
#  0.0118115215771001]

# %% [markdown]
# ### Case without simplification and without the reuse of contraction paths

# %%
#create new object to randomize the initial parameters

test_obj = avqite_quimb.Quimb_vqite(
    incar_file = "adaptvqite/adaptvqite/incars/incarN12g0.1",
    ansatz_file = "adaptvqite/adaptvqite/data/ansatz_inp.pkle",
    init_params = "random"
)

# %%
test_obj._params
# Out:
# [-0.05416632618173927,
#  0.09098661480299339,
#  0.09823323097088149,
#  -0.007815336940133394,
#  -0.024129600457379705,
#  0.051694602445462756,
#  -0.03568033416764396,
#  0.08460420718543543,
#  0.07147199257099787,
#  -0.031387318618810056,
#  -0.05691876660215205,
#  0.028642750154415836,
#  -0.023321866772278987,
#  0.09407749708267193,
#  -0.02002493431476307,
#  0.009376696808787915,
#  0.04423121020976034,
#  0.022283395473090106,
#  -0.07853291155282148,
#  -0.09532188449591734,
#  -0.029052212627036056]

# %%
#keyboard interupted before the convergence

test_obj.vqite(optimize_m='greedy',optimize_v='greedy',simplify_sequence = '',backend=None)
# Out:
# iter:  0 , M matrix time:  2.932677745819092 , V vector time:  6.793273210525513 , Energy:  -11.951438183638237
# iter:  1 , M matrix time:  0.24718093872070312 , V vector time:  6.606451034545898 , Energy:  -11.963482669071524
# iter:  2 , M matrix time:  0.2566697597503662 , V vector time:  6.559850215911865 , Energy:  -11.973687075162989
# iter:  3 , M matrix time:  0.24087810516357422 , V vector time:  6.73639988899231 , Energy:  -11.982330201263467
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 #keyboard interupted before the convergence
# ----> 3 test_obj.vqite(optimize_m='greedy',optimize_v='greedy',simplify_sequence = '',backend=None)
#
# File ~/avqite-quimb/avqite_quimb.py:366, in Quimb_vqite.vqite(self, delta, dt, optimize_m, optimize_v, **kwargs)
#     360     self.compute_m(
#     361         optimize=optimize_m,
#     362         which_nonzero=self.which_nonzero,
#     363         **kwargs
#     364     )
#     365 t2 = time.time()
# --> 366 self.compute_v(optimize=optimize_v,**kwargs)
#     367 t3 = time.time()
#     368 dthdt = self.get_dthdt(delta = delta, m = self._m, v= self._v)
#
# File ~/avqite-quimb/avqite_quimb.py:282, in Quimb_vqite.compute_v(self, **kwargs)
#     278 params2 = self._params.copy()
#     279 params2[mu] = params2[mu]-np.pi/2
#     280 self._v[mu] = np.real(
#     281     -1/2*(
# --> 282         self.h_exp_val(params=params1, **kwargs) -
#     283         self.h_exp_val(params=params2, **kwargs)
#     284     ) / 2
#     285 )
#
# File ~/avqite-quimb/avqite_quimb.py:433, in Quimb_vqite.h_exp_val(self, params, optimize, **kwargs)
#     431         h_exp_vals.append(exp_val)
#     432     else:
# --> 433         h_exp_vals.append( p_str_exp_eval(
#     434             qc=qc,
#     435             pauli_str=pauli_str,
#     436             optimize = optimize,
#     437             **kwargs
#     438         ) )
#     439 exp_value = sum([h_exp_vals[i]*self._H.coefs[i]
#     440                             for i in range(len(self._H.coefs))])
#     442 return exp_value
#
# File ~/avqite-quimb/avqite_quimb.py:816, in p_str_exp_eval(qc, pauli_str, **kwargs)
#     814 for i in range(1,len(where)):
#     815     operator = operator & qu.pauli(paulis[i])
# --> 816 exp_val = qc.local_expectation(
#     817     operator,
#     818     where,
#     819     **kwargs
#     820 )
#     821 return exp_val
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2882, in Circuit.local_expectation(self, G, where, optimize, simplify_sequence, simplify_atol, simplify_equalize_norms, backend, dtype, rehearse)
#    2874     where = (where,)
#    2876 fs_opts = {
#    2877     "seq": simplify_sequence,
#    2878     "atol": simplify_atol,
#    2879     "equalize_norms": simplify_equalize_norms,
#    2880 }
# -> 2882 rho = self.get_rdm_lightcone_simplified(where=where, **fs_opts)
#    2883 k_inds = tuple(self.ket_site_ind(i) for i in where)
#    2884 b_inds = tuple(self.bra_site_ind(i) for i in where)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2547, in Circuit.get_rdm_lightcone_simplified(self, where, seq, atol, equalize_norms)
#    2544 if key in self._storage:
#    2545     return self._storage[key].copy()
# -> 2547 ket_lc = self.get_psi_reverse_lightcone(where)
#    2549 k_inds = tuple(map(self.ket_site_ind, where))
#    2550 b_inds = tuple(map(self.bra_site_ind, where))
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2437, in Circuit.get_psi_reverse_lightcone(self, where, keep_psi0)
#    2434 if isinstance(where, numbers.Integral):
#    2435     where = (where,)
# -> 2437 psi = self.psi
#    2438 lightcone_tags = self.get_reverse_lightcone_tags(where)
#    2439 psi_lc = psi.select_any(lightcone_tags).view_like_(psi)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2310, in Circuit.psi(self)
#    2308 psi = self._psi.copy()
#    2309 psi.squeeze_()
# -> 2310 psi.astype_(psi.dtype)
#    2311 return psi
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:10786, in TensorNetwork.dtype(self)
#   10781 @property
#   10782 def dtype(self):
#   10783     """The dtype of this TensorNetwork, this is the minimal common type
#   10784     of all the tensors data.
#   10785     """
# > 10786     return get_common_dtype(*self.arrays)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:4365, in TensorNetwork.arrays(self)
#    4362 @property
#    4363 def arrays(self):
#    4364     """Get the tuple of raw arrays containing all the tensor network data."""
# -> 4365     return tuple(t.data for t in self)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:4365, in <genexpr>(.0)
#    4362 @property
#    4363 def arrays(self):
#    4364     """Get the tuple of raw arrays containing all the tensor network data."""
# -> 4365     return tuple(t.data for t in self)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:11210, in PTensor.data(self)
#   11208 @property
#   11209 def data(self):
# > 11210     return self._data.data
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/array_ops.py:561, in PArray.data(self)
#     558 @property
#     559 def data(self):
#     560     if self._data is None:
# --> 561         self._data = self._fn(self._params)
#     562     return self._data
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:891, in rzz_param_gen(params)
#     888 zero = 0.0 * theta
#     890 theta_2 = theta / 2
# --> 891 c00 = c11 = do("complex", do("cos", theta_2), do("sin", -theta_2))
#     892 c01 = c10 = do("complex", do("cos", theta_2), do("sin", theta_2))
#     894 # get a complex backend zero
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/autoray/autoray.py:81, in do(fn, like, *args, **kwargs)
#      79 backend = _choose_backend(fn, args, kwargs, like=like)
#      80 func = get_lib_fn(backend, fn)
# ---> 81 return func(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
test_obj._e
# Out:
# -11.982330201263467

# %%
test_obj._params
# Out:
# [-0.06226140026953602,
#  0.08171597855047126,
#  0.06334797572770498,
#  -0.011942481167927814,
#  -0.031424659122363904,
#  0.028788339089018705,
#  -0.022720047611084933,
#  0.04652365514988757,
#  0.04149069180484894,
#  -0.02606271926663517,
#  -0.05498753277837761,
#  0.02505800892085331,
#  -0.022645289001918947,
#  0.05033007761960039,
#  -0.02851085145553123,
#  0.0022598348157607567,
#  0.04092656500673264,
#  0.008900953083215112,
#  -0.06687313640631691,
#  -0.09904838204339546,
#  -0.03317935685521633]

# %% [markdown]
# ### Case without simplification and with the reuse of contraction paths

# %%
#create new object to randomize the initial parameters

test_obj = avqite_quimb.Quimb_vqite(
    incar_file = "adaptvqite/adaptvqite/incars/incarN12g0.1",
    ansatz_file = "adaptvqite/adaptvqite/data/ansatz_inp.pkle",
    init_params = "random"
)

# %%
test_obj._params
# Out:
# [0.058058319275709064,
#  0.007329825962727202,
#  0.017652961293478903,
#  -0.07674663380181379,
#  0.08916862031949388,
#  -0.007996649929673832,
#  -0.08595461723055711,
#  0.09459015352712025,
#  -0.07598758762994576,
#  0.07753064718613864,
#  0.006616644499552793,
#  0.0766061661829861,
#  0.05713740854097915,
#  0.03958904432560431,
#  -0.017356250424641353,
#  -0.022250057905495918,
#  -0.05569768048725912,
#  -0.07443487481838727,
#  0.09650871429286803,
#  -0.03918890691466595,
#  0.031146035498724578]

# %%
#Constructs the dictionary of contraction trees for evaluating
#the tensor corresponding to the expectation value of each Pauli
#string in the Hamiltonian.
#The expectation value is evaluated for the ansatz state.
#This dictionary of contraction trees can then be reused when
#evaluating expectation values for other values of parameters.

test_obj.h_terms_find_contractions(optimize='greedy',simplify_sequence = "")
test_obj.optimize_dict
# Out:
# {'XIIIIIIIIIII': <ContractionTree(N=31)>,
#  'IXIIIIIIIIII': <ContractionTree(N=47)>,
#  'IIXIIIIIIIII': <ContractionTree(N=49)>,
#  'IIIXIIIIIIII': <ContractionTree(N=59)>,
#  'IIIIXIIIIIII': <ContractionTree(N=45)>,
#  'IIIIIXIIIIII': <ContractionTree(N=55)>,
#  'IIIIIIXIIIII': <ContractionTree(N=27)>,
#  'IIIIIIIXIIII': <ContractionTree(N=69)>,
#  'IIIIIIIIXIII': <ContractionTree(N=65)>,
#  'IIIIIIIIIXII': <ContractionTree(N=65)>,
#  'IIIIIIIIIIXI': <ContractionTree(N=61)>,
#  'IIIIIIIIIIIX': <ContractionTree(N=51)>,
#  'ZZIIIIIIIIII': <ContractionTree(N=77)>,
#  'IZZIIIIIIIII': <ContractionTree(N=95)>,
#  'IIZZIIIIIIII': <ContractionTree(N=87)>,
#  'IIIZZIIIIIII': <ContractionTree(N=83)>,
#  'IIIIZZIIIIII': <ContractionTree(N=79)>,
#  'IIIIIZZIIIII': <ContractionTree(N=71)>,
#  'IIIIIIZZIIII': <ContractionTree(N=75)>,
#  'IIIIIIIZZIII': <ContractionTree(N=103)>,
#  'IIIIIIIIZZII': <ContractionTree(N=99)>,
#  'IIIIIIIIIZZI': <ContractionTree(N=95)>,
#  'IIIIIIIIIIZZ': <ContractionTree(N=85)>,
#  'ZIIIIIIIIIIZ': <ContractionTree(N=81)>}

# %%
#keyboard interupted before the convergence

test_obj.vqite(optimize_m='greedy',optimize_v=test_obj.optimize_dict,simplify_sequence = '',backend=None)
# Out:
# iter:  0 , M matrix time:  2.9749398231506348 , V vector time:  5.37437105178833 , Energy:  -11.93141027507699
# iter:  1 , M matrix time:  0.24294090270996094 , V vector time:  5.444319009780884 , Energy:  -11.946453388509001
# iter:  2 , M matrix time:  0.2798929214477539 , V vector time:  5.466997385025024 , Energy:  -11.959216444392814
# iter:  3 , M matrix time:  0.37015700340270996 , V vector time:  5.400464773178101 , Energy:  -11.9700400795175
# iter:  4 , M matrix time:  0.2795238494873047 , V vector time:  5.417373180389404 , Energy:  -11.979215496727107
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10774fc90>>
# Traceback (most recent call last):
#   File "/Users/Aleksei/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# iter:  5 , M matrix time:  0.326434850692749 , V vector time:  5.489617109298706 , Energy:  -11.986991218092856
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 #keyboard interupted before the convergence
# ----> 3 test_obj.vqite(optimize_m='greedy',optimize_v=test_obj.optimize_dict,simplify_sequence = '',backend=None)
#
# File ~/avqite-quimb/avqite_quimb.py:366, in Quimb_vqite.vqite(self, delta, dt, optimize_m, optimize_v, **kwargs)
#     360     self.compute_m(
#     361         optimize=optimize_m,
#     362         which_nonzero=self.which_nonzero,
#     363         **kwargs
#     364     )
#     365 t2 = time.time()
# --> 366 self.compute_v(optimize=optimize_v,**kwargs)
#     367 t3 = time.time()
#     368 dthdt = self.get_dthdt(delta = delta, m = self._m, v= self._v)
#
# File ~/avqite-quimb/avqite_quimb.py:283, in Quimb_vqite.compute_v(self, **kwargs)
#     278 params2 = self._params.copy()
#     279 params2[mu] = params2[mu]-np.pi/2
#     280 self._v[mu] = np.real(
#     281     -1/2*(
#     282         self.h_exp_val(params=params1, **kwargs) -
# --> 283         self.h_exp_val(params=params2, **kwargs)
#     284     ) / 2
#     285 )
#
# File ~/avqite-quimb/avqite_quimb.py:425, in Quimb_vqite.h_exp_val(self, params, optimize, **kwargs)
#     423 for pauli_str in self._H.paulis:
#     424     if type(optimize) == dict:
# --> 425         exp_val = p_str_exp_eval(
#     426             qc=qc,
#     427             pauli_str=pauli_str,
#     428             optimize = optimize[pauli_str],
#     429             **kwargs
#     430         )
#     431         h_exp_vals.append(exp_val)
#     432     else:
#
# File ~/avqite-quimb/avqite_quimb.py:816, in p_str_exp_eval(qc, pauli_str, **kwargs)
#     814 for i in range(1,len(where)):
#     815     operator = operator & qu.pauli(paulis[i])
# --> 816 exp_val = qc.local_expectation(
#     817     operator,
#     818     where,
#     819     **kwargs
#     820 )
#     821 return exp_val
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2882, in Circuit.local_expectation(self, G, where, optimize, simplify_sequence, simplify_atol, simplify_equalize_norms, backend, dtype, rehearse)
#    2874     where = (where,)
#    2876 fs_opts = {
#    2877     "seq": simplify_sequence,
#    2878     "atol": simplify_atol,
#    2879     "equalize_norms": simplify_equalize_norms,
#    2880 }
# -> 2882 rho = self.get_rdm_lightcone_simplified(where=where, **fs_opts)
#    2883 k_inds = tuple(self.ket_site_ind(i) for i in where)
#    2884 b_inds = tuple(self.bra_site_ind(i) for i in where)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2552, in Circuit.get_rdm_lightcone_simplified(self, where, seq, atol, equalize_norms)
#    2549 k_inds = tuple(map(self.ket_site_ind, where))
#    2550 b_inds = tuple(map(self.bra_site_ind, where))
# -> 2552 bra_lc = ket_lc.conj().reindex(dict(zip(k_inds, b_inds)))
#    2553 rho_lc = bra_lc | ket_lc
#    2555 # don't want to simplify site indices in region away
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:4134, in TensorNetwork.reindex(self, index_map, inplace)
#    4126 def reindex(self, index_map, inplace=False):
#    4127     """Rename indices for all tensors in this network, optionally in-place.
#    4128
#    4129     Parameters
#    (...)
#    4132         Mapping of pairs ``{old_ind: new_ind, ...}``.
#    4133     """
# -> 4134     tn = self if inplace else self.copy()
#    4136     tids = oset_union(tn.ind_map.get(ix, oset()) for ix in index_map)
#    4138     for tid in tids:
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:3797, in TensorNetwork.copy(self, virtual, deep)
#    3795 if deep:
#    3796     return copy.deepcopy(self)
# -> 3797 return self.__class__(self, virtual=virtual)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:3647, in TensorNetwork.__init__(self, ts, virtual, check_collisions)
#    3645 self.tensor_map = dict()
#    3646 for tid, t in ts.tensor_map.items():
# -> 3647     self.tensor_map[tid] = t if virtual else t.copy()
#    3648     self.tensor_map[tid].add_owner(self, tid)
#    3649 self._inner_inds = ts._inner_inds.copy()
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:11191, in PTensor.copy(self)
#   11188 def copy(self):
#   11189     """Copy this parametrized tensor."""
#   11190     return PTensor.from_parray(
# > 11191         self._data.copy(),
#   11192         inds=self.inds,
#   11193         tags=self.tags,
#   11194         left_inds=self.left_inds,
#   11195     )
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/array_ops.py:536, in PArray.copy(self)
#     535 def copy(self):
# --> 536     new = PArray(self.fn, self.params, self.shape)
#     537     new._data = self._data  # for efficiency
#     538     return new
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/array_ops.py:569, in PArray.shape(self)
#     567 _shape_fn_id = id(self.fn)
#     568 if (self._shape is None) or (self._shape_fn_id != _shape_fn_id):
# --> 569     self._shape = self.data.shape
#     570     self._shape_fn_id = _shape_fn_id
#     571 return self._shape
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/array_ops.py:561, in PArray.data(self)
#     558 @property
#     559 def data(self):
#     560     if self._data is None:
# --> 561         self._data = self._fn(self._params)
#     562     return self._data
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/cytoolz/functoolz.pyx:521, in cytoolz.functoolz.Compose.__call__()
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/cytoolz/functoolz.pyx:521, in cytoolz.functoolz.Compose.__call__()
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:902, in rzz_param_gen(params)
#     895 zero = do("complex", zero, zero)
#     897 data = (
#     898     (((c00, zero), (zero, zero)), ((zero, c01), (zero, zero))),
#     899     (((zero, zero), (c10, zero)), ((zero, zero), (zero, c11))),
#     900 )
# --> 902 return recursive_stack(data)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:55, in recursive_stack(x)
#      53 if not isinstance(x, (list, tuple)):
#      54     return x
# ---> 55 return do("stack", tuple(map(recursive_stack, x)))
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:55, in recursive_stack(x)
#      53 if not isinstance(x, (list, tuple)):
#      54     return x
# ---> 55 return do("stack", tuple(map(recursive_stack, x)))
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:55, in recursive_stack(x)
#      53 if not isinstance(x, (list, tuple)):
#      54     return x
# ---> 55 return do("stack", tuple(map(recursive_stack, x)))
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/autoray/autoray.py:81, in do(fn, like, *args, **kwargs)
#      79 backend = _choose_backend(fn, args, kwargs, like=like)
#      80 func = get_lib_fn(backend, fn)
# ---> 81 return func(*args, **kwargs)
#
# File <__array_function__ internals>:200, in stack(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:471, in stack(arrays, axis, out, dtype, casting)
#     469 sl = (slice(None),) * axis + (_nx.newaxis,)
#     470 expanded_arrays = [arr[sl] for arr in arrays]
# --> 471 return _nx.concatenate(expanded_arrays, axis=axis, out=out,
#     472                        dtype=dtype, casting=casting)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
test_obj._e
# Out:
# -11.986991218092856

# %%
test_obj._params
# Out:
# [0.046088332308533514,
#  0.0015765907773374038,
#  0.01003027093800997,
#  -0.08640714652552342,
#  0.03447393715930716,
#  -0.02922579185572137,
#  -0.08447874704319501,
#  0.03782512118427334,
#  -0.062361514525673956,
#  0.04463230155503703,
#  -0.015607527517655179,
#  0.06407660724888577,
#  0.03939110632215539,
#  0.03676409702649491,
#  -0.030185774338683843,
#  -0.016946674555648456,
#  -0.06439066360434742,
#  -0.06412567496233916,
#  0.04160122464507844,
#  -0.04057647123045863,
#  0.021485522774905463]
