# %%
"""
This notebook demonstrates how to use tensor-network implementation 
of the VQITE simulation.
The main code, relevant description, and package requirements are 
listed in avqite_quimb.py.
"""

# %%
import numpy as np
import scipy
import pickle
import time
from tqdm import tqdm
from typing import (
    List,
    Optional,
    Tuple,
    Union
)
import random
import importlib

import quimb as qu
import quimb.tensor as qtn

import cotengra as ctg

import avqite_quimb

importlib.reload(avqite_quimb)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# <module 'avqite_quimb' from '/Users/Aleksei/avqite-quimb/avqite_quimb.py'>

# %%
#File ansatz_inp.pkle contains the final ansatz generated by AVQITE

test_obj = avqite_quimb.Quimb_vqite(
    incar_file = "adaptvqite/adaptvqite/incars/incarN12g0.1",
    ansatz_file = "adaptvqite/adaptvqite/data/ansatz_inp.pkle",
    init_params = "random"
)

# %%
#Initial parameter values

test_obj._params
# Out:
# [-0.009702388889680669,
#  0.07210815868286621,
#  -0.03309571286102418,
#  0.06393442982786998,
#  -0.06056783238554771,
#  -0.09525232726371424,
#  0.05829953383769548,
#  0.06484438250431304,
#  -0.09721269576888279,
#  0.07365307364226056,
#  0.006146268138535027,
#  0.02329588184887961,
#  -0.02069391610514182,
#  0.010215807610669564,
#  -0.09382772641551769,
#  0.0633103497387621,
#  0.02290392301358031,
#  -0.02424565827099953,
#  0.06384407853768356,
#  -0.054225739409433274,
#  -0.04048210551312195]

# %% [markdown]
# ### AVQITE results

# %% [markdown]
# e = -12.02998224

# %%
test_obj._params_solution
# Out:
# [-0.03373891838404348,
#  -0.050078497033246835,
#  -0.04991639034653487,
#  -0.024964345407657868,
#  -0.049755843269241644,
#  -0.04989684794910913,
#  -0.049917295159514666,
#  -0.04991848825801717,
#  -0.03373880318968922,
#  0.023566888103175317,
#  -0.04993780407632377,
#  -9.060913728609124e-06,
#  -2.1727417925979092e-05,
#  -2.0666081313686814e-05,
#  -0.04975599567846892,
#  -0.01613088640936399,
#  -0.01613095926996059,
#  -2.1592095145783832e-05,
#  -0.07350141136452552,
#  9.920607797867385e-05,
#  -0.02496434540765841]

# %% [markdown]
# ### Case with simplification 'CSR' and without the reuse of contraction paths

# %%
#keyboard interupted before the convergence

test_obj.vqite(opt_m='greedy',opt_v='greedy',simp = 'CSR',backend=None)
# Out:
# iter:  0 , M matrix time:  4.428608179092407 , V vector time:  10.663022756576538 , Energy:  (-11.953699724108839-4.014207494367459e-17j)
# iter:  1 , M matrix time:  0.34958696365356445 , V vector time:  10.866551160812378 , Energy:  (-11.965351097969059-4.108367121313957e-17j)
# iter:  2 , M matrix time:  0.35512709617614746 , V vector time:  10.700991868972778 , Energy:  (-11.975231745533568+8.306342621391064e-18j)
# iter:  3 , M matrix time:  0.35091090202331543 , V vector time:  10.590353012084961 , Energy:  (-11.98360796392174-1.0674953295114738e-18j)
# iter:  4 , M matrix time:  0.3550300598144531 , V vector time:  10.565065860748291 , Energy:  (-11.990706753920701+2.1262587198837853e-17j)
# iter:  5 , M matrix time:  0.3538360595703125 , V vector time:  10.518142938613892 , Energy:  (-11.996721444400151+3.8076162628877554e-19j)
# iter:  6 , M matrix time:  0.3883330821990967 , V vector time:  10.566450834274292 , Energy:  (-12.001816540917563-2.1821452698492728e-17j)
# iter:  7 , M matrix time:  0.3567333221435547 , V vector time:  10.609217643737793 , Energy:  (-12.006131908514819+5.60731711197023e-18j)
# iter:  8 , M matrix time:  0.35436081886291504 , V vector time:  10.536597967147827 , Energy:  (-12.009786375962095+6.56445369997168e-19j)
# iter:  9 , M matrix time:  0.35266995429992676 , V vector time:  10.63784408569336 , Energy:  (-12.0128808353807+1.3004488019735446e-17j)
# iter:  10 , M matrix time:  0.3536660671234131 , V vector time:  10.538301944732666 , Energy:  (-12.015500901937958+3.1508226026862675e-18j)
# iter:  11 , M matrix time:  0.3539268970489502 , V vector time:  10.512188196182251 , Energy:  (-12.017719191253072+1.0595890768454176e-17j)
# iter:  12 , M matrix time:  0.3825211524963379 , V vector time:  10.518945932388306 , Energy:  (-12.019597266138545+9.971021109286601e-18j)
# iter:  13 , M matrix time:  0.38211488723754883 , V vector time:  10.655800104141235 , Energy:  (-12.021187298565286+8.900038115455032e-18j)
# iter:  14 , M matrix time:  0.349078893661499 , V vector time:  10.532724142074585 , Energy:  (-12.022533487058094+3.0784310969240908e-18j)
# iter:  15 , M matrix time:  0.35094404220581055 , V vector time:  10.504576921463013 , Energy:  (-12.023673264356633-5.011259007736068e-18j)
# iter:  16 , M matrix time:  0.3523287773132324 , V vector time:  10.51201319694519 , Energy:  (-12.024638325397442+1.3888460405496667e-17j)
# iter:  17 , M matrix time:  0.35187602043151855 , V vector time:  10.500663042068481 , Energy:  (-12.025455501516571+8.446694114383734e-18j)
# iter:  18 , M matrix time:  0.3539750576019287 , V vector time:  10.504645109176636 , Energy:  (-12.026147503229387+3.921082886785302e-18j)
# iter:  19 , M matrix time:  0.34873414039611816 , V vector time:  10.514954805374146 , Energy:  (-12.026733550831924+9.5031995215802e-18j)
# iter:  20 , M matrix time:  0.35004115104675293 , V vector time:  10.539142847061157 , Energy:  (-12.027229909381878-1.1389365710267708e-17j)
# iter:  21 , M matrix time:  0.3518979549407959 , V vector time:  10.854678869247437 , Energy:  (-12.02765034227213+1.8035249474496015e-18j)
# iter:  22 , M matrix time:  0.35259485244750977 , V vector time:  10.597121000289917 , Energy:  (-12.028006495579527-1.4606754464582077e-17j)
# iter:  23 , M matrix time:  0.3520941734313965 , V vector time:  10.500749826431274 , Energy:  (-12.028308223616987+1.3139124760938121e-17j)
# iter:  24 , M matrix time:  0.35603809356689453 , V vector time:  10.4846830368042 , Energy:  (-12.02856386460156+1.4915458863075755e-17j)
# iter:  25 , M matrix time:  0.35044312477111816 , V vector time:  10.607883930206299 , Energy:  (-12.028780474043486-1.4753616658691278e-17j)
# iter:  26 , M matrix time:  0.3525550365447998 , V vector time:  10.511122941970825 , Energy:  (-12.028964022331948+8.2337899949385e-19j)
# iter:  27 , M matrix time:  0.3533821105957031 , V vector time:  10.51557207107544 , Energy:  (-12.029119562015456+1.702864588486618e-17j)
# iter:  28 , M matrix time:  0.3530919551849365 , V vector time:  10.534785985946655 , Energy:  (-12.029251369432808+1.8458048212113585e-17j)
# iter:  29 , M matrix time:  0.35448598861694336 , V vector time:  10.500923871994019 , Energy:  (-12.029363064621295+1.410318915498104e-17j)
# iter:  30 , M matrix time:  0.3479900360107422 , V vector time:  10.515858888626099 , Energy:  (-12.029457712807398-6.34130613037127e-18j)
# iter:  31 , M matrix time:  0.35074377059936523 , V vector time:  10.507587909698486 , Energy:  (-12.029537910260487-3.0689588903146097e-17j)
# iter:  32 , M matrix time:  0.36210107803344727 , V vector time:  10.538141250610352 , Energy:  (-12.029605856852648-5.47505878178829e-19j)
# iter:  33 , M matrix time:  0.3525047302246094 , V vector time:  10.53376817703247 , Energy:  (-12.029663417313376+1.8305729881604468e-17j)
# iter:  34 , M matrix time:  0.3511359691619873 , V vector time:  10.614128828048706 , Energy:  (-12.029712172880709+4.352213929310418e-17j)
# iter:  35 , M matrix time:  0.35393214225769043 , V vector time:  10.53201174736023 , Energy:  (-12.029753464817093-1.7860293266212627e-17j)
# iter:  36 , M matrix time:  0.35500288009643555 , V vector time:  10.617875814437866 , Energy:  (-12.02978843106271-1.9320845323541395e-18j)
# iter:  37 , M matrix time:  0.35294413566589355 , V vector time:  10.786757946014404 , Energy:  (-12.0298180371268+2.9209277875606886e-17j)
# iter:  38 , M matrix time:  0.35073304176330566 , V vector time:  10.526789903640747 , Energy:  (-12.02984310216006+4.622218567675351e-18j)
# iter:  39 , M matrix time:  0.3528728485107422 , V vector time:  10.515058040618896 , Energy:  (-12.029864321005322-2.0134934686267974e-17j)
# iter:  40 , M matrix time:  0.3570687770843506 , V vector time:  10.50886607170105 , Energy:  (-12.029882282890599-1.208900005636947e-17j)
# iter:  41 , M matrix time:  0.3527190685272217 , V vector time:  10.556191682815552 , Energy:  (-12.029897487303643-2.9419735063474314e-18j)
# iter:  42 , M matrix time:  0.3538060188293457 , V vector time:  10.545983791351318 , Energy:  (-12.029910357509706-1.698740528045631e-17j)
# iter:  43 , M matrix time:  0.3517932891845703 , V vector time:  10.679377794265747 , Energy:  (-12.02992125205149+1.5279037966584394e-17j)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 #keyboard interupted before the convergence
# ----> 3 test_obj.vqite(opt_m='greedy',opt_v='greedy',simp = 'CSR',backend=None)
#
# File ~/avqite-quimb/avqite_quimb.py:347, in Quimb_vqite.vqite(self, opt_m, opt_v, simp, backend)
#     340     self.compute_m(
#     341         opt=opt_m,
#     342         simp=simp,
#     343         backend = backend,
#     344         which_nonzero=self.which_nonzero
#     345     )
#     346 t2 = time.time()
# --> 347 self.compute_v(opt=opt_v,simp=simp,backend = backend)
#     348 t3 = time.time()
#     349 dthdt = self.get_dthdt(delta = 1e-4, m = self._m, v= self._v)
#
# File ~/avqite-quimb/avqite_quimb.py:304, in Quimb_vqite.compute_v(self, opt, simp, backend)
#     295 params2 = self._params.copy()
#     296 params2[mu] = params2[mu]-np.pi/2
#     297 self._v[mu] = np.real(-1/2*(
#     298     self.h_exp_val(
#     299         params = params1,
#     300         opt = opt,
#     301         simp=simp,
#     302         backend = backend
#     303     ) -
# --> 304     self.h_exp_val(
#     305         params = params2,
#     306         opt = opt,
#     307         simp=simp,
#     308         backend = backend)
#     309 ) / 2 )
#
# File ~/avqite-quimb/avqite_quimb.py:419, in Quimb_vqite.h_exp_val(self, params, opt, simp, backend)
#     417         h_exp_vals.append(exp_val)
#     418     else:
# --> 419         h_exp_vals.append( p_str_exp_eval(
#     420             qc=qc,
#     421             pauli_str=pauli_str,
#     422             opt = opt,
#     423             simp=simp,
#     424             backend = backend
#     425         ) )
#     426 exp_value = sum([h_exp_vals[i]*self._H.coefs[i]
#     427                             for i in range(len(self._H.coefs))])
#     429 return exp_value
#
# File ~/avqite-quimb/avqite_quimb.py:804, in p_str_exp_eval(qc, pauli_str, opt, simp, backend)
#     802 for i in range(1,len(where)):
#     803     operator = operator & qu.pauli(paulis[i])
# --> 804 exp_val = qc.local_expectation(
#     805     operator,
#     806     where,
#     807     optimize=opt,
#     808     simplify_sequence=simp,
#     809     backend=backend
#     810 )
#     811 return exp_val
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2882, in Circuit.local_expectation(self, G, where, optimize, simplify_sequence, simplify_atol, simplify_equalize_norms, backend, dtype, rehearse)
#    2874     where = (where,)
#    2876 fs_opts = {
#    2877     "seq": simplify_sequence,
#    2878     "atol": simplify_atol,
#    2879     "equalize_norms": simplify_equalize_norms,
#    2880 }
# -> 2882 rho = self.get_rdm_lightcone_simplified(where=where, **fs_opts)
#    2883 k_inds = tuple(self.ket_site_ind(i) for i in where)
#    2884 b_inds = tuple(self.bra_site_ind(i) for i in where)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2552, in Circuit.get_rdm_lightcone_simplified(self, where, seq, atol, equalize_norms)
#    2549 k_inds = tuple(map(self.ket_site_ind, where))
#    2550 b_inds = tuple(map(self.bra_site_ind, where))
# -> 2552 bra_lc = ket_lc.conj().reindex(dict(zip(k_inds, b_inds)))
#    2553 rho_lc = bra_lc | ket_lc
#    2555 # don't want to simplify site indices in region away
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:4134, in TensorNetwork.reindex(self, index_map, inplace)
#    4126 def reindex(self, index_map, inplace=False):
#    4127     """Rename indices for all tensors in this network, optionally in-place.
#    4128
#    4129     Parameters
#    (...)
#    4132         Mapping of pairs ``{old_ind: new_ind, ...}``.
#    4133     """
# -> 4134     tn = self if inplace else self.copy()
#    4136     tids = oset_union(tn.ind_map.get(ix, oset()) for ix in index_map)
#    4138     for tid in tids:
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:3797, in TensorNetwork.copy(self, virtual, deep)
#    3795 if deep:
#    3796     return copy.deepcopy(self)
# -> 3797 return self.__class__(self, virtual=virtual)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:3647, in TensorNetwork.__init__(self, ts, virtual, check_collisions)
#    3645 self.tensor_map = dict()
#    3646 for tid, t in ts.tensor_map.items():
# -> 3647     self.tensor_map[tid] = t if virtual else t.copy()
#    3648     self.tensor_map[tid].add_owner(self, tid)
#    3649 self._inner_inds = ts._inner_inds.copy()
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:11191, in PTensor.copy(self)
#   11188 def copy(self):
#   11189     """Copy this parametrized tensor."""
#   11190     return PTensor.from_parray(
# > 11191         self._data.copy(),
#   11192         inds=self.inds,
#   11193         tags=self.tags,
#   11194         left_inds=self.left_inds,
#   11195     )
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/array_ops.py:536, in PArray.copy(self)
#     535 def copy(self):
# --> 536     new = PArray(self.fn, self.params, self.shape)
#     537     new._data = self._data  # for efficiency
#     538     return new
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/array_ops.py:569, in PArray.shape(self)
#     567 _shape_fn_id = id(self.fn)
#     568 if (self._shape is None) or (self._shape_fn_id != _shape_fn_id):
# --> 569     self._shape = self.data.shape
#     570     self._shape_fn_id = _shape_fn_id
#     571 return self._shape
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/array_ops.py:561, in PArray.data(self)
#     558 @property
#     559 def data(self):
#     560     if self._data is None:
# --> 561         self._data = self._fn(self._params)
#     562     return self._data
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/cytoolz/functoolz.pyx:521, in cytoolz.functoolz.Compose.__call__()
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/cytoolz/functoolz.pyx:521, in cytoolz.functoolz.Compose.__call__()
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:902, in rzz_param_gen(params)
#     895 zero = do("complex", zero, zero)
#     897 data = (
#     898     (((c00, zero), (zero, zero)), ((zero, c01), (zero, zero))),
#     899     (((zero, zero), (c10, zero)), ((zero, zero), (zero, c11))),
#     900 )
# --> 902 return recursive_stack(data)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:55, in recursive_stack(x)
#      53 if not isinstance(x, (list, tuple)):
#      54     return x
# ---> 55 return do("stack", tuple(map(recursive_stack, x)))
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:55, in recursive_stack(x)
#      53 if not isinstance(x, (list, tuple)):
#      54     return x
# ---> 55 return do("stack", tuple(map(recursive_stack, x)))
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:55, in recursive_stack(x)
#      53 if not isinstance(x, (list, tuple)):
#      54     return x
# ---> 55 return do("stack", tuple(map(recursive_stack, x)))
#
# KeyboardInterrupt:

# %%
test_obj._e
# Out:
# (-12.02992125205149+1.5279037966584394e-17j)

# %%
test_obj._params
# Out:
# [-0.024727967420971914,
#  -0.03358443864393842,
#  -0.049789952455839934,
#  0.029797552912237273,
#  -0.05007111036100096,
#  -0.051646401040262684,
#  -0.04533826001248691,
#  -0.04706556704988363,
#  -0.04601461397608408,
#  0.04552343524692717,
#  -0.04857989381039969,
#  -0.0027333072580612914,
#  2.838029879060708e-06,
#  -0.0015969313270324634,
#  -0.050925827079480866,
#  -0.003550067451076351,
#  -0.02358986034589234,
#  -0.00040079252132076257,
#  -0.09080224219294959,
#  -0.014651840174901141,
#  -0.07461898242807365]

# %% [markdown]
# ### Case without simplification and without the reuse of contraction paths

# %%
#create new object to randomize the initial parameters

test_obj = avqite_quimb.Quimb_vqite(
    incar_file = "adaptvqite/adaptvqite/incars/incarN12g0.1",
    ansatz_file = "adaptvqite/adaptvqite/data/ansatz_inp.pkle",
    init_params = "random"
)

# %%
test_obj._params
# Out:
# [-0.042912269914985916,
#  0.04159247342755093,
#  -0.016912991218384715,
#  0.09163886934979135,
#  -0.08425617673103572,
#  -0.043628280288779075,
#  0.009263917405058053,
#  0.0441096039829558,
#  -0.03603990120456134,
#  0.001788290393984801,
#  -0.019614725310198214,
#  0.0034353927736269635,
#  -0.03230502658089984,
#  -0.02489995644297524,
#  -0.09650382513016593,
#  0.09642820705822752,
#  -0.05061166629195762,
#  -0.011176881733628255,
#  0.05608706903267152,
#  -0.04623272591422576,
#  -0.01678048125235812]

# %%
#keyboard interupted before the convergence

test_obj.vqite(opt_m='greedy',opt_v='greedy',simp = '',backend=None)
# Out:
# iter:  0 , M matrix time:  2.9907708168029785 , V vector time:  6.622769117355347 , Energy:  -11.979415521893674
# iter:  1 , M matrix time:  0.2714989185333252 , V vector time:  6.600974798202515 , Energy:  -11.987152059763286
# iter:  2 , M matrix time:  0.31113672256469727 , V vector time:  6.591634273529053 , Energy:  -11.993709128036453
# iter:  3 , M matrix time:  0.29171299934387207 , V vector time:  6.6096954345703125 , Energy:  -11.999265498049981
# iter:  4 , M matrix time:  0.30898094177246094 , V vector time:  6.625264883041382 , Energy:  -12.003972984624308
# iter:  5 , M matrix time:  0.29401612281799316 , V vector time:  6.606688976287842 , Energy:  -12.00796051590752
# iter:  6 , M matrix time:  0.32367491722106934 , V vector time:  6.585188150405884 , Energy:  -12.011337610514493
# iter:  7 , M matrix time:  0.3148190975189209 , V vector time:  6.594236850738525 , Energy:  -12.014197307412864
# iter:  8 , M matrix time:  0.31154727935791016 , V vector time:  6.614098787307739 , Energy:  -12.016618619363518
# iter:  9 , M matrix time:  0.31624388694763184 , V vector time:  6.62338924407959 , Energy:  -12.018668602454264
# iter:  10 , M matrix time:  0.3148038387298584 , V vector time:  6.599557876586914 , Energy:  -12.020404124285632
# iter:  11 , M matrix time:  0.29267001152038574 , V vector time:  6.583570718765259 , Energy:  -12.021873384545863
# iter:  12 , M matrix time:  0.29181480407714844 , V vector time:  6.621474027633667 , Energy:  -12.023117220086524
# iter:  13 , M matrix time:  0.3065783977508545 , V vector time:  6.585687637329102 , Energy:  -12.024170219579872
# iter:  14 , M matrix time:  0.30256199836730957 , V vector time:  6.57405686378479 , Energy:  -12.025061672396532
# iter:  15 , M matrix time:  0.3097519874572754 , V vector time:  6.575057029724121 , Energy:  -12.025816375397083
# iter:  16 , M matrix time:  0.3293588161468506 , V vector time:  6.768450021743774 , Energy:  -12.02645531867014
# iter:  17 , M matrix time:  0.29167914390563965 , V vector time:  6.682931184768677 , Energy:  -12.026996268111874
# iter:  18 , M matrix time:  0.24309301376342773 , V vector time:  6.626191139221191 , Energy:  -12.027454259992652
# iter:  19 , M matrix time:  0.2574589252471924 , V vector time:  6.616423845291138 , Energy:  -12.027842020424835
# iter:  20 , M matrix time:  0.2630879878997803 , V vector time:  6.629475116729736 , Energy:  -12.028170320806188
# iter:  21 , M matrix time:  0.25847291946411133 , V vector time:  6.701370000839233 , Energy:  -12.02844827875398
# iter:  22 , M matrix time:  0.3172037601470947 , V vector time:  6.627182245254517 , Energy:  -12.028683612706251
# iter:  23 , M matrix time:  0.3158719539642334 , V vector time:  6.699616193771362 , Energy:  -12.02888285721087
# iter:  24 , M matrix time:  0.30417895317077637 , V vector time:  6.583778142929077 , Energy:  -12.029051544920248
# iter:  25 , M matrix time:  0.31543707847595215 , V vector time:  6.675940752029419 , Energy:  -12.029194360436346
# iter:  26 , M matrix time:  0.31276988983154297 , V vector time:  6.705512285232544 , Energy:  -12.029315270388059
# iter:  27 , M matrix time:  0.3070409297943115 , V vector time:  6.584762096405029 , Energy:  -12.029417633457998
# iter:  28 , M matrix time:  0.30574488639831543 , V vector time:  6.662599086761475 , Energy:  -12.029504293497743
# iter:  29 , M matrix time:  0.32053494453430176 , V vector time:  6.663954019546509 , Energy:  -12.029577658373116
# iter:  30 , M matrix time:  0.3090329170227051 , V vector time:  6.608927011489868 , Energy:  -12.029639766754663
# iter:  31 , M matrix time:  0.3087186813354492 , V vector time:  6.558457136154175 , Energy:  -12.029692344709758
# iter:  32 , M matrix time:  0.30785274505615234 , V vector time:  6.561875104904175 , Energy:  -12.029736853652624
# iter:  33 , M matrix time:  0.3072488307952881 , V vector time:  6.554656982421875 , Energy:  -12.029774530961353
# iter:  34 , M matrix time:  0.3089771270751953 , V vector time:  6.566617965698242 , Energy:  -12.029806424368617
# iter:  35 , M matrix time:  0.30962610244750977 , V vector time:  6.603264093399048 , Energy:  -12.029833421066744
# iter:  36 , M matrix time:  0.30966997146606445 , V vector time:  6.564208030700684 , Energy:  -12.02985627233046
# iter:  37 , M matrix time:  0.3109281063079834 , V vector time:  6.624410152435303 , Energy:  -12.02987561434421
# iter:  38 , M matrix time:  0.30796194076538086 , V vector time:  6.553532123565674 , Energy:  -12.029891985821092
# iter:  39 , M matrix time:  0.31011486053466797 , V vector time:  6.5416951179504395 , Energy:  -12.02990584291259
# iter:  40 , M matrix time:  0.31040000915527344 , V vector time:  6.563668966293335 , Energy:  -12.029917571831799
# iter:  41 , M matrix time:  0.30562710762023926 , V vector time:  6.567791938781738 , Energy:  -12.029927499546048
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 #keyboard interupted before the convergence
# ----> 3 test_obj.vqite(opt_m='greedy',opt_v='greedy',simp = '',backend=None)
#
# File ~/avqite-quimb/avqite_quimb.py:347, in Quimb_vqite.vqite(self, opt_m, opt_v, simp, backend)
#     340     self.compute_m(
#     341         opt=opt_m,
#     342         simp=simp,
#     343         backend = backend,
#     344         which_nonzero=self.which_nonzero
#     345     )
#     346 t2 = time.time()
# --> 347 self.compute_v(opt=opt_v,simp=simp,backend = backend)
#     348 t3 = time.time()
#     349 dthdt = self.get_dthdt(delta = 1e-4, m = self._m, v= self._v)
#
# File ~/avqite-quimb/avqite_quimb.py:304, in Quimb_vqite.compute_v(self, opt, simp, backend)
#     295 params2 = self._params.copy()
#     296 params2[mu] = params2[mu]-np.pi/2
#     297 self._v[mu] = np.real(-1/2*(
#     298     self.h_exp_val(
#     299         params = params1,
#     300         opt = opt,
#     301         simp=simp,
#     302         backend = backend
#     303     ) -
# --> 304     self.h_exp_val(
#     305         params = params2,
#     306         opt = opt,
#     307         simp=simp,
#     308         backend = backend)
#     309 ) / 2 )
#
# File ~/avqite-quimb/avqite_quimb.py:419, in Quimb_vqite.h_exp_val(self, params, opt, simp, backend)
#     417         h_exp_vals.append(exp_val)
#     418     else:
# --> 419         h_exp_vals.append( p_str_exp_eval(
#     420             qc=qc,
#     421             pauli_str=pauli_str,
#     422             opt = opt,
#     423             simp=simp,
#     424             backend = backend
#     425         ) )
#     426 exp_value = sum([h_exp_vals[i]*self._H.coefs[i]
#     427                             for i in range(len(self._H.coefs))])
#     429 return exp_value
#
# File ~/avqite-quimb/avqite_quimb.py:804, in p_str_exp_eval(qc, pauli_str, opt, simp, backend)
#     802 for i in range(1,len(where)):
#     803     operator = operator & qu.pauli(paulis[i])
# --> 804 exp_val = qc.local_expectation(
#     805     operator,
#     806     where,
#     807     optimize=opt,
#     808     simplify_sequence=simp,
#     809     backend=backend
#     810 )
#     811 return exp_val
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2901, in Circuit.local_expectation(self, G, where, optimize, simplify_sequence, simplify_atol, simplify_equalize_norms, backend, dtype, rehearse)
#    2898 rhoG = rho | TG
#    2900 rhoG.full_simplify_(output_inds=output_inds, **fs_opts)
# -> 2901 rhoG.astype_(dtype)
#    2903 if rehearse == "tn":
#    2904     return rhoG
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:10795, in TensorNetwork.astype(self, dtype, inplace)
#   10793 TN = self if inplace else self.copy()
#   10794 for t in TN:
# > 10795     t.astype(dtype, inplace=True)
#   10796 return TN
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:1905, in Tensor.astype(self, dtype, inplace)
#    1903 T = self if inplace else self.copy()
#    1904 if T.dtype != dtype:
# -> 1905     T.modify(apply=lambda data: astype(data, dtype))
#    1906 return T
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:1569, in Tensor.modify(self, **kwargs)
#    1566 if kwargs:
#    1567     raise ValueError(f"Option(s) {kwargs} not valid.")
# -> 1569 if len(self.inds) != ndim(self.data):
#    1570     raise ValueError(
#    1571         "Mismatch between number of data dimensions and "
#    1572         "number of indices supplied."
#    1573     )
#    1575 if self.left_inds and any(i not in self.inds for i in self.left_inds):
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:11210, in PTensor.data(self)
#   11208 @property
#   11209 def data(self):
# > 11210     return self._data.data
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/array_ops.py:561, in PArray.data(self)
#     558 @property
#     559 def data(self):
#     560     if self._data is None:
# --> 561         self._data = self._fn(self._params)
#     562     return self._data
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/cytoolz/functoolz.pyx:521, in cytoolz.functoolz.Compose.__call__()
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/cytoolz/functoolz.pyx:521, in cytoolz.functoolz.Compose.__call__()
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:902, in rzz_param_gen(params)
#     895 zero = do("complex", zero, zero)
#     897 data = (
#     898     (((c00, zero), (zero, zero)), ((zero, c01), (zero, zero))),
#     899     (((zero, zero), (c10, zero)), ((zero, zero), (zero, c11))),
#     900 )
# --> 902 return recursive_stack(data)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:55, in recursive_stack(x)
#      53 if not isinstance(x, (list, tuple)):
#      54     return x
# ---> 55 return do("stack", tuple(map(recursive_stack, x)))
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/autoray/autoray.py:81, in do(fn, like, *args, **kwargs)
#      79 backend = _choose_backend(fn, args, kwargs, like=like)
#      80 func = get_lib_fn(backend, fn)
# ---> 81 return func(*args, **kwargs)
#
# File <__array_function__ internals>:200, in stack(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:471, in stack(arrays, axis, out, dtype, casting)
#     469 sl = (slice(None),) * axis + (_nx.newaxis,)
#     470 expanded_arrays = [arr[sl] for arr in arrays]
# --> 471 return _nx.concatenate(expanded_arrays, axis=axis, out=out,
#     472                        dtype=dtype, casting=casting)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
test_obj._e
# Out:
# -12.029927499546048

# %%
test_obj._params
# Out:
# [-0.03775464505720231,
#  -0.05052243474223147,
#  -0.04917059390534211,
#  0.03198338817771341,
#  -0.05080641415017967,
#  -0.05067299826797954,
#  -0.046003456548693776,
#  -0.04715048221870861,
#  -0.02968258427239105,
#  0.010601448919552049,
#  -0.0491041598187347,
#  -0.0016923621528222668,
#  -9.123161836680344e-05,
#  -0.0029665070713743003,
#  -0.05119203733241102,
#  -0.016954732259089982,
#  -0.013469580578768098,
#  -0.00017871814520350711,
#  -0.05734452041001983,
#  0.0018875040808701807,
#  -0.0764359624235666]

# %% [markdown]
# ### Case without simplification and with the reuse of contraction paths

# %%
#create new object to randomize the initial parameters

test_obj = avqite_quimb.Quimb_vqite(
    incar_file = "adaptvqite/adaptvqite/incars/incarN12g0.1",
    ansatz_file = "adaptvqite/adaptvqite/data/ansatz_inp.pkle",
    init_params = "random"
)

# %%
test_obj._params
# Out:
# [0.09067237884622575,
#  -0.06815834463228473,
#  0.038075247117500294,
#  0.03088530800802719,
#  -0.027541747300550395,
#  -0.04229361819950888,
#  0.0669032126746058,
#  -0.0427225299699328,
#  -0.08608064888468969,
#  0.030179655589461035,
#  -0.08117224762241962,
#  0.07613590504903953,
#  0.023963061992453683,
#  -0.0242575334431282,
#  -0.03828372925383943,
#  -0.02643430308814891,
#  0.06886716423273515,
#  -0.08277400656090761,
#  -0.0975263255704628,
#  -0.04280881802332333,
#  -0.008210757697990886]

# %%
#Constructs the dictionary of contraction trees for evaluating
#the tensor corresponding to the expectation value of each Pauli
#string in the Hamiltonian.
#The expectation value is evaluated for the ansatz state.
#This dictionary of contraction trees can then be reused when
#evaluating expectation values for other values of parameters.

test_obj.h_terms_find_contractions(opt='greedy',simp = "")
test_obj.opt_dict
# Out:
# {'XIIIIIIIIIII': <ContractionTree(N=31)>,
#  'IXIIIIIIIIII': <ContractionTree(N=47)>,
#  'IIXIIIIIIIII': <ContractionTree(N=49)>,
#  'IIIXIIIIIIII': <ContractionTree(N=59)>,
#  'IIIIXIIIIIII': <ContractionTree(N=45)>,
#  'IIIIIXIIIIII': <ContractionTree(N=55)>,
#  'IIIIIIXIIIII': <ContractionTree(N=27)>,
#  'IIIIIIIXIIII': <ContractionTree(N=69)>,
#  'IIIIIIIIXIII': <ContractionTree(N=65)>,
#  'IIIIIIIIIXII': <ContractionTree(N=65)>,
#  'IIIIIIIIIIXI': <ContractionTree(N=61)>,
#  'IIIIIIIIIIIX': <ContractionTree(N=51)>,
#  'ZZIIIIIIIIII': <ContractionTree(N=77)>,
#  'IZZIIIIIIIII': <ContractionTree(N=95)>,
#  'IIZZIIIIIIII': <ContractionTree(N=87)>,
#  'IIIZZIIIIIII': <ContractionTree(N=83)>,
#  'IIIIZZIIIIII': <ContractionTree(N=79)>,
#  'IIIIIZZIIIII': <ContractionTree(N=71)>,
#  'IIIIIIZZIIII': <ContractionTree(N=75)>,
#  'IIIIIIIZZIII': <ContractionTree(N=103)>,
#  'IIIIIIIIZZII': <ContractionTree(N=99)>,
#  'IIIIIIIIIZZI': <ContractionTree(N=95)>,
#  'IIIIIIIIIIZZ': <ContractionTree(N=85)>,
#  'ZIIIIIIIIIIZ': <ContractionTree(N=81)>}

# %%
#keyboard interupted before the convergence

test_obj.vqite(opt_m='greedy',opt_v=test_obj.opt_dict,simp = '',backend=None)
# Out:
# iter:  0 , M matrix time:  2.904154062271118 , V vector time:  5.526017665863037 , Energy:  -11.957887474314006
# iter:  1 , M matrix time:  0.28077220916748047 , V vector time:  5.4218690395355225 , Energy:  -11.968904702965812
# iter:  2 , M matrix time:  0.269301176071167 , V vector time:  5.59779691696167 , Energy:  -11.978247163973432
# iter:  3 , M matrix time:  0.28118085861206055 , V vector time:  5.487776041030884 , Energy:  -11.986167085914044
# iter:  4 , M matrix time:  0.3420140743255615 , V vector time:  5.4877989292144775 , Energy:  -11.992879205342469
# iter:  5 , M matrix time:  0.2872350215911865 , V vector time:  5.642566919326782 , Energy:  -11.998566277097126
# iter:  6 , M matrix time:  0.2793443202972412 , V vector time:  5.670182704925537 , Energy:  -12.003383781706217
# iter:  7 , M matrix time:  0.24632978439331055 , V vector time:  5.440683126449585 , Energy:  -12.007463931278245
# iter:  8 , M matrix time:  0.34148383140563965 , V vector time:  5.4254961013793945 , Energy:  -12.010919082245318
# iter:  9 , M matrix time:  0.2720041275024414 , V vector time:  5.4938459396362305 , Energy:  -12.013844650536923
# iter:  10 , M matrix time:  0.2745249271392822 , V vector time:  5.4722580909729 , Energy:  -12.016321608054112
# iter:  11 , M matrix time:  0.27231407165527344 , V vector time:  5.365854978561401 , Energy:  -12.018418624071593
# iter:  12 , M matrix time:  0.3303101062774658 , V vector time:  5.351679086685181 , Energy:  -12.020193902594926
# iter:  13 , M matrix time:  0.3456532955169678 , V vector time:  5.368354797363281 , Energy:  -12.021696757048176
# iter:  14 , M matrix time:  0.27699899673461914 , V vector time:  5.406867027282715 , Energy:  -12.022968956831981
# iter:  15 , M matrix time:  0.27338695526123047 , V vector time:  5.3568150997161865 , Energy:  -12.024045875650232
# iter:  16 , M matrix time:  0.24399089813232422 , V vector time:  5.363651990890503 , Energy:  -12.02495746820429
# iter:  17 , M matrix time:  0.33123207092285156 , V vector time:  5.3595170974731445 , Energy:  -12.025729099161332
# iter:  18 , M matrix time:  0.3390991687774658 , V vector time:  5.357983827590942 , Energy:  -12.026382245775203
# iter:  19 , M matrix time:  0.27895283699035645 , V vector time:  5.414562225341797 , Energy:  -12.026935093014524
# iter:  20 , M matrix time:  0.2940659523010254 , V vector time:  5.4159910678863525 , Energy:  -12.027403037558857
# iter:  21 , M matrix time:  0.27862977981567383 , V vector time:  5.35314416885376 , Energy:  -12.027799114661454
# iter:  22 , M matrix time:  0.3420090675354004 , V vector time:  5.362505912780762 , Energy:  -12.02813435974359
# iter:  23 , M matrix time:  0.2715928554534912 , V vector time:  5.4288740158081055 , Energy:  -12.028418114734135
# iter:  24 , M matrix time:  0.2790489196777344 , V vector time:  5.356279134750366 , Energy:  -12.028658287601093
# iter:  25 , M matrix time:  0.2562439441680908 , V vector time:  5.368321180343628 , Energy:  -12.028861572211799
# iter:  26 , M matrix time:  0.3363680839538574 , V vector time:  5.3565309047698975 , Energy:  -12.02903363456335
# iter:  27 , M matrix time:  0.2676992416381836 , V vector time:  5.418158769607544 , Energy:  -12.029179270505473
# iter:  28 , M matrix time:  0.27414822578430176 , V vector time:  5.419472932815552 , Energy:  -12.02930253930182
# iter:  29 , M matrix time:  0.27898406982421875 , V vector time:  5.421198129653931 , Energy:  -12.029406876717644
# iter:  30 , M matrix time:  0.324692964553833 , V vector time:  5.476083040237427 , Energy:  -12.029495190762836
# iter:  31 , M matrix time:  0.32822299003601074 , V vector time:  5.353103160858154 , Energy:  -12.029569942744075
# iter:  32 , M matrix time:  0.2787940502166748 , V vector time:  5.420513868331909 , Energy:  -12.029633215875872
# iter:  33 , M matrix time:  0.2781870365142822 , V vector time:  5.344773054122925 , Energy:  -12.02968677335743
# iter:  34 , M matrix time:  0.24817514419555664 , V vector time:  5.359688758850098 , Energy:  -12.029732107530773
# iter:  35 , M matrix time:  0.33635592460632324 , V vector time:  5.362022161483765 , Energy:  -12.029770481488713
# iter:  36 , M matrix time:  0.3365459442138672 , V vector time:  5.346437931060791 , Energy:  -12.029802964291662
# iter:  37 , M matrix time:  0.27928709983825684 , V vector time:  5.423003911972046 , Energy:  -12.02983046077467
# iter:  38 , M matrix time:  0.28693699836730957 , V vector time:  5.420420169830322 , Energy:  -12.02985373677551
# iter:  39 , M matrix time:  0.2800610065460205 , V vector time:  5.375831127166748 , Energy:  -12.029873440487247
# iter:  40 , M matrix time:  0.3323550224304199 , V vector time:  5.355811834335327 , Energy:  -12.029890120530604
# iter:  41 , M matrix time:  0.27309393882751465 , V vector time:  5.417536020278931 , Energy:  -12.029904241250145
# iter:  42 , M matrix time:  0.28258585929870605 , V vector time:  5.368035078048706 , Energy:  -12.029916195660684
# iter:  43 , M matrix time:  0.24293112754821777 , V vector time:  5.349447011947632 , Energy:  -12.029926316405012
# iter:  44 , M matrix time:  0.3294100761413574 , V vector time:  5.352165222167969 , Energy:  -12.029934885028345
# iter:  45 , M matrix time:  0.27965593338012695 , V vector time:  5.408427000045776 , Energy:  -12.029942139828108
# iter:  46 , M matrix time:  0.273421049118042 , V vector time:  5.407942056655884 , Energy:  -12.029948282497962
# iter:  47 , M matrix time:  0.28402185440063477 , V vector time:  5.359858989715576 , Energy:  -12.029953483751108
# iter:  48 , M matrix time:  0.3288130760192871 , V vector time:  5.404516935348511 , Energy:  -12.02995788807978
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 #keyboard interupted before the convergence
# ----> 3 test_obj.vqite(opt_m='greedy',opt_v=test_obj.opt_dict,simp = '',backend=None)
#
# File ~/avqite-quimb/avqite_quimb.py:347, in Quimb_vqite.vqite(self, opt_m, opt_v, simp, backend)
#     340     self.compute_m(
#     341         opt=opt_m,
#     342         simp=simp,
#     343         backend = backend,
#     344         which_nonzero=self.which_nonzero
#     345     )
#     346 t2 = time.time()
# --> 347 self.compute_v(opt=opt_v,simp=simp,backend = backend)
#     348 t3 = time.time()
#     349 dthdt = self.get_dthdt(delta = 1e-4, m = self._m, v= self._v)
#
# File ~/avqite-quimb/avqite_quimb.py:304, in Quimb_vqite.compute_v(self, opt, simp, backend)
#     295 params2 = self._params.copy()
#     296 params2[mu] = params2[mu]-np.pi/2
#     297 self._v[mu] = np.real(-1/2*(
#     298     self.h_exp_val(
#     299         params = params1,
#     300         opt = opt,
#     301         simp=simp,
#     302         backend = backend
#     303     ) -
# --> 304     self.h_exp_val(
#     305         params = params2,
#     306         opt = opt,
#     307         simp=simp,
#     308         backend = backend)
#     309 ) / 2 )
#
# File ~/avqite-quimb/avqite_quimb.py:410, in Quimb_vqite.h_exp_val(self, params, opt, simp, backend)
#     408 for pauli_str in self._H.paulis:
#     409     if type(opt) == dict:
# --> 410         exp_val = p_str_exp_eval(
#     411             qc=qc,
#     412             pauli_str=pauli_str,
#     413             opt = opt[pauli_str],
#     414             simp=simp,
#     415             backend = backend
#     416         )
#     417         h_exp_vals.append(exp_val)
#     418     else:
#
# File ~/avqite-quimb/avqite_quimb.py:804, in p_str_exp_eval(qc, pauli_str, opt, simp, backend)
#     802 for i in range(1,len(where)):
#     803     operator = operator & qu.pauli(paulis[i])
# --> 804 exp_val = qc.local_expectation(
#     805     operator,
#     806     where,
#     807     optimize=opt,
#     808     simplify_sequence=simp,
#     809     backend=backend
#     810 )
#     811 return exp_val
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2882, in Circuit.local_expectation(self, G, where, optimize, simplify_sequence, simplify_atol, simplify_equalize_norms, backend, dtype, rehearse)
#    2874     where = (where,)
#    2876 fs_opts = {
#    2877     "seq": simplify_sequence,
#    2878     "atol": simplify_atol,
#    2879     "equalize_norms": simplify_equalize_norms,
#    2880 }
# -> 2882 rho = self.get_rdm_lightcone_simplified(where=where, **fs_opts)
#    2883 k_inds = tuple(self.ket_site_ind(i) for i in where)
#    2884 b_inds = tuple(self.bra_site_ind(i) for i in where)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2547, in Circuit.get_rdm_lightcone_simplified(self, where, seq, atol, equalize_norms)
#    2544 if key in self._storage:
#    2545     return self._storage[key].copy()
# -> 2547 ket_lc = self.get_psi_reverse_lightcone(where)
#    2549 k_inds = tuple(map(self.ket_site_ind, where))
#    2550 b_inds = tuple(map(self.bra_site_ind, where))
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2437, in Circuit.get_psi_reverse_lightcone(self, where, keep_psi0)
#    2434 if isinstance(where, numbers.Integral):
#    2435     where = (where,)
# -> 2437 psi = self.psi
#    2438 lightcone_tags = self.get_reverse_lightcone_tags(where)
#    2439 psi_lc = psi.select_any(lightcone_tags).view_like_(psi)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/circuit.py:2309, in Circuit.psi(self)
#    2307 # make sure all same dtype and drop singlet dimensions
#    2308 psi = self._psi.copy()
# -> 2309 psi.squeeze_()
#    2310 psi.astype_(psi.dtype)
#    2311 return psi
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:9010, in TensorNetwork.squeeze(self, fuse, include, exclude, inplace)
#    9007 tn = self if inplace else self.copy()
#    9009 for t in tn:
# -> 9010     t.squeeze_(include=include, exclude=exclude)
#    9012 if fuse:
#    9013     tn.fuse_multibonds_(include=include, exclude=exclude)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:2532, in Tensor.squeeze(self, include, exclude, inplace)
#    2529 t = self if inplace else self.copy()
#    2531 # handles case of scalar as well
# -> 2532 if 1 not in t.shape:
#    2533     return t
#    2535 new_inds = []
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:1874, in Tensor.shape(self)
#    1871 @property
#    1872 def shape(self):
#    1873     """The size of each dimension."""
# -> 1874     return shape(self._data)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/autoray/autoray.py:922, in Composed.__call__(self, like, *args, **kwargs)
#     921 def __call__(self, *args, like=None, **kwargs):
# --> 922     backend = _choose_backend(self._name, args, kwargs, like=like)
#     923     # `get_lib_fn` will call `make_function` if the function doesn't exist
#     924     fn = get_lib_fn(backend, self._name)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/autoray/autoray.py:402, in _choose_backend(fn, args, kwargs, like)
#     395 """Private function to choose a backend based on function name and
#     396 signature, which passes args and kwargs by reference for performance and
#     397 also to allow injection of dtype and device arguments for array creation
#     398 routines.
#     399 """
#     400 if like is None:
#     401     # infer from function call (or global backend)
# --> 402     return _infer_auto(fn, args, kwargs)
#     403 elif isinstance(like, str):
#     404     # explicit backend
#     405     return like
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/autoray/autoray.py:93, in _default_infer_from_sig(fn, *args, **kwargs)
#      87 def _default_infer_from_sig(fn, *args, **kwargs):
#      88     """This is the default backend dispatcher, used if no global backend has
#      89     been set. Hot swapping this function out as below avoids having to check
#      90     manually for a global backend or worse, a thread aware global backend, on
#      91     every call to ``do``.
#      92     """
# ---> 93     return _DISPATCHERS[fn](*args, **kwargs)
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/autoray/autoray.py:1390, in default_dispatcher(args, kwargs)
#    1388 def default_dispatcher(args, kwargs):
#    1389     """Try to infer backend from first argument passed to function."""
# -> 1390     return infer_backend(args[0])
#
# File ~/anaconda3/envs/adaptvqite-quimb/lib/python3.11/site-packages/autoray/autoray.py:301, in infer_backend(array)
#     296 def infer_backend(array):
#     297     """Get the name of the library that defined the class of ``array`` - unless
#     298     ``array`` is directly a subclass of ``numpy.ndarray``, in which case assume
#     299     ``numpy`` is the desired backend.
#     300     """
# --> 301     return _infer_class_backend_cached(array.__class__)
#
# KeyboardInterrupt:

# %%
test_obj._e
# Out:
# -12.02995788807978

# %%
test_obj._params
# Out:
# [-0.03163675638321584,
#  -0.0489877830276273,
#  -0.04458514308413373,
#  -0.004272956182420266,
#  -0.049463360923907816,
#  -0.05132589798418473,
#  -0.04865983534679364,
#  -0.049864963758030054,
#  -0.03369668968709007,
#  0.03477078064920372,
#  -0.050521961484139545,
#  0.000130419804270247,
#  0.0018458099823682132,
#  0.00020247509416626138,
#  -0.04964430210703753,
#  -0.017316759363532185,
#  -0.014802386418249418,
#  -0.005332852904975242,
#  -0.08509516588669942,
#  -0.002124481844401296,
#  -0.04336902188975564]
